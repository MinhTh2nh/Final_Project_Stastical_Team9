# %%
# Import libraries for data manipulation and analysis
import pandas as pd
import numpy as np

# Import libraries for working with dates and times
import datetime as dt

# Import TensorFlow and Keras libraries for building and training neural networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2

# Import scikit-learn library for various metrics and preprocessing tools
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# Import matplotlib library for creating plots and charts
import matplotlib.pyplot as plt

# Magic command to display plots inline in the Jupyter Notebook
# %matplotlib inline
# Out:
# C:\Users\Dell\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# Read in the HAGL dataset from a CSV file
df=pd.read_csv("E:\HAGLdataset.csv")

# %%
# Convert the 'date' column to a datetime data type
df['date']=pd.to_datetime(df.date,format='%m/%d/%Y')

# %%
#set the date as the index
df=df.set_index(pd.DatetimeIndex(df['date'].values))

# %%
# Create a new DataFrame containing only the 'date' and 'price' columns
df1 = pd.DataFrame(df, columns=['date', 'price'])

# Set the index of the DataFrame to the 'date' column
df1.index = df1.date

# Drop the 'date' column from the DataFrame
df1.drop('date', axis=1, inplace=True)

# %%
# Plot the 'price' column of the 'df' DataFrame
plt.figure(figsize=(10,5))
plt.plot(df['price'])
plt.title('Price of HAG')
plt.show()

# %%
# Split the 'df1' DataFrame into train and test datasets

# Convert the 'df1' DataFrame to a NumPy array
data = df1.values

# Calculate the number of rows to use for the train dataset
t = .8
t = int(t * len(df))

# Extract the train dataset from the data array
train_data = data[:t]

# Extract the test dataset from the data array
test_data = data[t:]

# %%
# Scale the data using a MinMaxScaler

# Create a MinMaxScaler object with a specified range
sc = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the data and transform the data
sc_train = sc.fit_transform(data)

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 30th value
for i in range(5, len(train_data)):
    # Append the last 5 values to the x_train array
    x_train.append(sc_train[i-5:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an LSTM layer with 128 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(LSTM(units=64, input_shape=(x_train.shape[1], 1), return_sequences=True,kernel_regularizer=l2(0.01)))

# Add an LSTM layer with 64 units
model.add(LSTM(units=64, return_sequences=True))

# Add a dropout layer with a rate of 0.5
#model.add(Dropout(0.5))

# Add an LSTM layer with 64 units
model.add(LSTM(units=64, return_sequences=False))

# Add a dropout layer with a rate of 0.5
model.add(Dropout(0.5))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_8-2.hdf5'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
#
# Epoch 1: loss improved from inf to 0.15564, saving model to save_model_8-2.hdf5
# 29/29 - 12s - loss: 0.1556 - 12s/epoch - 411ms/step
# Epoch 2/80
#
# Epoch 2: loss improved from 0.15564 to 0.06095, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0610 - 492ms/epoch - 17ms/step
# Epoch 3/80
#
# Epoch 3: loss improved from 0.06095 to 0.04922, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0492 - 443ms/epoch - 15ms/step
# Epoch 4/80
#
# Epoch 4: loss improved from 0.04922 to 0.04129, saving model to save_model_8-2.hdf5
# 29/29 - 1s - loss: 0.0413 - 552ms/epoch - 19ms/step
# Epoch 5/80
#
# Epoch 5: loss improved from 0.04129 to 0.04033, saving model to save_model_8-2.hdf5
# 29/29 - 1s - loss: 0.0403 - 584ms/epoch - 20ms/step
# Epoch 6/80
#
# Epoch 6: loss improved from 0.04033 to 0.03993, saving model to save_model_8-2.hdf5
# 29/29 - 1s - loss: 0.0399 - 572ms/epoch - 20ms/step
# Epoch 7/80
#
# Epoch 7: loss improved from 0.03993 to 0.03921, saving model to save_model_8-2.hdf5
# 29/29 - 1s - loss: 0.0392 - 698ms/epoch - 24ms/step
# Epoch 8/80
#
# Epoch 8: loss improved from 0.03921 to 0.03803, saving model to save_model_8-2.hdf5
# 29/29 - 1s - loss: 0.0380 - 556ms/epoch - 19ms/step
# Epoch 9/80
#
# Epoch 9: loss improved from 0.03803 to 0.03771, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0377 - 459ms/epoch - 16ms/step
# Epoch 10/80
#
# Epoch 10: loss improved from 0.03771 to 0.03562, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0356 - 370ms/epoch - 13ms/step
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.03562
# 29/29 - 0s - loss: 0.0366 - 418ms/epoch - 14ms/step
# Epoch 12/80
#
# Epoch 12: loss improved from 0.03562 to 0.03394, saving model to save_model_8-2.hdf5
# 29/29 - 1s - loss: 0.0339 - 567ms/epoch - 20ms/step
# Epoch 13/80
#
# Epoch 13: loss improved from 0.03394 to 0.03259, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0326 - 486ms/epoch - 17ms/step
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.03259
# 29/29 - 0s - loss: 0.0330 - 422ms/epoch - 15ms/step
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.03259
# 29/29 - 0s - loss: 0.0331 - 346ms/epoch - 12ms/step
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.03259
# 29/29 - 0s - loss: 0.0328 - 428ms/epoch - 15ms/step
# Epoch 17/80
#
# Epoch 17: loss improved from 0.03259 to 0.03068, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0307 - 476ms/epoch - 16ms/step
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.03068
# 29/29 - 0s - loss: 0.0328 - 441ms/epoch - 15ms/step
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.03068
# 29/29 - 0s - loss: 0.0327 - 480ms/epoch - 17ms/step
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.03068
# 29/29 - 0s - loss: 0.0314 - 373ms/epoch - 13ms/step
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.03068
# 29/29 - 0s - loss: 0.0307 - 491ms/epoch - 17ms/step
# Epoch 22/80
#
# Epoch 22: loss improved from 0.03068 to 0.02992, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0299 - 493ms/epoch - 17ms/step
# Epoch 23/80
#
# Epoch 23: loss improved from 0.02992 to 0.02884, saving model to save_model_8-2.hdf5
# 29/29 - 1s - loss: 0.0288 - 766ms/epoch - 26ms/step
# Epoch 24/80
#
# Epoch 24: loss improved from 0.02884 to 0.02790, saving model to save_model_8-2.hdf5
# 29/29 - 1s - loss: 0.0279 - 620ms/epoch - 21ms/step
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.02790
# 29/29 - 0s - loss: 0.0300 - 450ms/epoch - 16ms/step
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.02790
# 29/29 - 0s - loss: 0.0282 - 381ms/epoch - 13ms/step
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.02790
# 29/29 - 0s - loss: 0.0280 - 459ms/epoch - 16ms/step
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.02790
# 29/29 - 0s - loss: 0.0284 - 420ms/epoch - 14ms/step
# Epoch 29/80
#
# Epoch 29: loss improved from 0.02790 to 0.02675, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0267 - 497ms/epoch - 17ms/step
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.02675
# 29/29 - 0s - loss: 0.0295 - 431ms/epoch - 15ms/step
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.02675
# 29/29 - 0s - loss: 0.0282 - 388ms/epoch - 13ms/step
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.02675
# 29/29 - 0s - loss: 0.0275 - 387ms/epoch - 13ms/step
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.02675
# 29/29 - 0s - loss: 0.0287 - 386ms/epoch - 13ms/step
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.02675
# 29/29 - 0s - loss: 0.0270 - 417ms/epoch - 14ms/step
# Epoch 35/80
#
# Epoch 35: loss improved from 0.02675 to 0.02644, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0264 - 443ms/epoch - 15ms/step
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.02644
# 29/29 - 0s - loss: 0.0272 - 397ms/epoch - 14ms/step
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.02644
# 29/29 - 0s - loss: 0.0271 - 478ms/epoch - 16ms/step
# Epoch 38/80
#
# Epoch 38: loss improved from 0.02644 to 0.02605, saving model to save_model_8-2.hdf5
# 29/29 - 1s - loss: 0.0260 - 530ms/epoch - 18ms/step
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.02605
# 29/29 - 0s - loss: 0.0262 - 468ms/epoch - 16ms/step
# Epoch 40/80
#
# Epoch 40: loss improved from 0.02605 to 0.02592, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0259 - 465ms/epoch - 16ms/step
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.02592
# 29/29 - 0s - loss: 0.0267 - 455ms/epoch - 16ms/step
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.02592
# 29/29 - 0s - loss: 0.0260 - 427ms/epoch - 15ms/step
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.02592
# 29/29 - 0s - loss: 0.0263 - 401ms/epoch - 14ms/step
# Epoch 44/80
#
# Epoch 44: loss improved from 0.02592 to 0.02570, saving model to save_model_8-2.hdf5
# 29/29 - 1s - loss: 0.0257 - 640ms/epoch - 22ms/step
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.02570
# 29/29 - 0s - loss: 0.0262 - 471ms/epoch - 16ms/step
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.02570
# 29/29 - 0s - loss: 0.0262 - 447ms/epoch - 15ms/step
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.02570
# 29/29 - 1s - loss: 0.0260 - 646ms/epoch - 22ms/step
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.02570
# 29/29 - 0s - loss: 0.0273 - 383ms/epoch - 13ms/step
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.02570
# 29/29 - 0s - loss: 0.0257 - 364ms/epoch - 13ms/step
# Epoch 50/80
#
# Epoch 50: loss improved from 0.02570 to 0.02505, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0250 - 398ms/epoch - 14ms/step
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.02505
# 29/29 - 0s - loss: 0.0254 - 353ms/epoch - 12ms/step
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.02505
# 29/29 - 0s - loss: 0.0260 - 364ms/epoch - 13ms/step
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.02505
# 29/29 - 0s - loss: 0.0261 - 347ms/epoch - 12ms/step
# Epoch 54/80
#
# Epoch 54: loss improved from 0.02505 to 0.02443, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0244 - 392ms/epoch - 14ms/step
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.02443
# 29/29 - 0s - loss: 0.0246 - 336ms/epoch - 12ms/step
# Epoch 56/80
#
# Epoch 56: loss improved from 0.02443 to 0.02417, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0242 - 389ms/epoch - 13ms/step
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.02417
# 29/29 - 0s - loss: 0.0253 - 356ms/epoch - 12ms/step
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.02417
# 29/29 - 0s - loss: 0.0244 - 333ms/epoch - 11ms/step
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.02417
# 29/29 - 0s - loss: 0.0245 - 349ms/epoch - 12ms/step
# Epoch 60/80
#
# Epoch 60: loss improved from 0.02417 to 0.02378, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0238 - 393ms/epoch - 14ms/step
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.02378
# 29/29 - 0s - loss: 0.0265 - 350ms/epoch - 12ms/step
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.02378
# 29/29 - 0s - loss: 0.0255 - 349ms/epoch - 12ms/step
# Epoch 63/80
#
# Epoch 63: loss improved from 0.02378 to 0.02357, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0236 - 384ms/epoch - 13ms/step
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.02357
# 29/29 - 0s - loss: 0.0236 - 345ms/epoch - 12ms/step
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.02357
# 29/29 - 0s - loss: 0.0249 - 335ms/epoch - 12ms/step
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.02357
# 29/29 - 0s - loss: 0.0246 - 340ms/epoch - 12ms/step
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.02357
# 29/29 - 0s - loss: 0.0242 - 322ms/epoch - 11ms/step
# Epoch 68/80
#
# Epoch 68: loss improved from 0.02357 to 0.02310, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0231 - 415ms/epoch - 14ms/step
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.02310
# 29/29 - 0s - loss: 0.0234 - 374ms/epoch - 13ms/step
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.02310
# 29/29 - 0s - loss: 0.0240 - 339ms/epoch - 12ms/step
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.02310
# 29/29 - 0s - loss: 0.0235 - 345ms/epoch - 12ms/step
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.02310
# 29/29 - 0s - loss: 0.0254 - 341ms/epoch - 12ms/step
# Epoch 73/80
#
# Epoch 73: loss improved from 0.02310 to 0.02292, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0229 - 382ms/epoch - 13ms/step
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.02292
# 29/29 - 0s - loss: 0.0235 - 378ms/epoch - 13ms/step
# Epoch 75/80
#
# Epoch 75: loss improved from 0.02292 to 0.02241, saving model to save_model_8-2.hdf5
# 29/29 - 0s - loss: 0.0224 - 428ms/epoch - 15ms/step
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.02241
# 29/29 - 0s - loss: 0.0242 - 365ms/epoch - 13ms/step
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.02241
# 29/29 - 0s - loss: 0.0236 - 369ms/epoch - 13ms/step
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.02241
# 29/29 - 0s - loss: 0.0232 - 360ms/epoch - 12ms/step
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.02241
# 29/29 - 0s - loss: 0.0232 - 356ms/epoch - 12ms/step
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.02241
# 29/29 - 0s - loss: 0.0245 - 488ms/epoch - 17ms/step

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Use the model to make predictions on the x_train data
y_train_predict = model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 46/46 [==============================] - 2s 5ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-5:].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(5, test.shape[0]):
    x_test.append(sc_test[i-5:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[t:]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 12/12 [==============================] - 0s 4ms/step

# %%
#Train data
# Calculate performance metrics for the training data
mae = mean_absolute_error(y_train, y_train_predict)  # Mean Absolute Error (MAE)
mape = mean_absolute_percentage_error(y_train, y_train_predict)  # Mean Absolute Percentage Error (MAPE)
mse = mean_squared_error(y_train, y_train_predict)  # Mean Squared Error (MSE)
rmse = np.sqrt(mse)  # Root Mean Squared Error (RMSE)
r2 = r2_score(y_train, y_train_predict)  # R-squared (R2)

# Print the performance metrics
print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 227.56
# MAPE: 3.67%
# MSE: 95439.08
# RMSE: 308.93
# R2: 0.98

# %%
#Test data
mae = mean_absolute_error(y_test, y_test_predict)
mape = mean_absolute_percentage_error(y_test, y_test_predict)
mse = mean_squared_error(y_test, y_test_predict)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_test_predict)

print(f"MAE: {mae:.2f}")
print(f"MAPE: {mape * 100:.2f}%")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R2: {r2:.2f}")
# Out:
# MAE: 477.87
# MAPE: 5.08%
# MSE: 415306.65
# RMSE: 644.44
# R2: 0.96

# %%
# Create DataFrames for the training and test data
train_data1 = df1[5:t]
test_data1 = df1[t:]

# Create a plot to compare the predicted and true values for the training and test data
plt.figure(figsize=(16,5))
plt.plot(df1, label='Annual price', color='r')
train_data1['pred'] = y_train_predict
plt.plot(train_data1['pred'], label='Train predict Price', color='g')
test_data1['pred'] = y_test_predict
plt.plot(test_data1['pred'], label='Test predict Price', color='b')
plt.title('Compare Predict Price and Annual Price')
plt.xlabel('date')
plt.ylabel('Price OF HAG(VND)')
plt.legend()
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22804\612936592.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data1['pred'] = y_train_predict
# C:\Users\Dell\AppData\Local\Temp\ipykernel_22804\612936592.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['pred'] = y_test_predict

# %%
# Create a plot to compare the predicted and true values for the test data
plt.figure(figsize=(10,5))
plt.plot(test_data1[['price','pred']])
plt.legend(['Test','Predictions'])
plt.title('HAG', fontsize=18)
plt.show()
